# %% [markdown]
# ### PRIM and Dimensional stacking

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx

from ema_workbench import (Model, CategoricalParameter,
                           ScalarOutcome, IntegerParameter, RealParameter,
                           MultiprocessingEvaluator, Policy, Scenario)

from dike_model_function import DikeNetwork  # @UnresolvedImport


def sum_over(*args):
    return sum(args)

from ema_workbench import (Model, )

from ema_workbench.em_framework.evaluators import perform_experiments
from ema_workbench.em_framework.samplers import sample_uncertainties
from ema_workbench.util import ema_logging
import time

from problem_formulation import get_model_for_problem_formulation


ema_logging.log_to_stderr(ema_logging.INFO)

#choose problem formulation number, between 0-5
#each problem formulation has its own list of outcomes
dike_model, planning_steps = get_model_for_problem_formulation(6)

# %%
uncertainties = dike_model.uncertainties
levers = dike_model.levers 

import copy
uncertainties = copy.deepcopy(dike_model.uncertainties)
levers = copy.deepcopy(dike_model.levers)

# %%
#running the model through EMA workbench
from ema_workbench import (MultiprocessingEvaluator, ema_logging,
                           perform_experiments, SequentialEvaluator)
ema_logging.log_to_stderr(ema_logging.INFO)
 
with MultiprocessingEvaluator(dike_model) as evaluator:
    experiments, outcomes = evaluator.perform_experiments(scenarios=10, policies = 3)
# Out:
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 100 scenarios * 3 policies * 1 model(s) = 300 experiments
# [MainProcess/INFO] 30 cases completed
# [MainProcess/INFO] 60 cases completed
# [MainProcess/INFO] 90 cases completed
# [MainProcess/INFO] 120 cases completed
# [MainProcess/INFO] 150 cases completed
# [MainProcess/INFO] 180 cases completed
# [MainProcess/INFO] 210 cases completed
# [MainProcess/INFO] 240 cases completed
# [MainProcess/INFO] 270 cases completed
# [MainProcess/INFO] 300 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool

# %%
experiments = pd.read_csv('Experiments_from_Exploration_1000scenarios_pf5.csv')
outcomes_load_DF = pd.read_csv('Outcomes_from_Exploration_1000scenarios_pf5.csv')

# %%
from ema_workbench.analysis import prim

data = outcomes_load_DF['A.4_Expected Annual Damage 0']

y = data > 2000


prim_alg = prim.Prim(experiments,y, threshold=0.8)
box1 = prim_alg.find_box()
# Out:
# [MainProcess/INFO] policy dropped from analysis because only a single category
# [MainProcess/INFO] model dropped from analysis because only a single category
# [MainProcess/INFO] 10 points remaining, containing 3 cases of interest
# [MainProcess/INFO] mean: 1.0, mass: 0.3, coverage: 1.0, density: 1.0 restricted_dimensions: 2

# %%
box1.show_tradeoff()
plt.show()

# %%
box1.inspect(style='graph')
plt.show()

# %%
fig = box1.show_pairs_scatter()
# Out:
# C:\Users\Ted\Anaconda3\envs\MBDM\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8     True
# 9     True
# Name: A.4_Expected Annual Damage 0, dtype: bool

# %%
from ema_workbench.analysis import dimensional_stacking
dimensional_stacking.create_pivot_plot(experiments, y)
plt.show()
# Out:
# [MainProcess/INFO] policy dropped from analysis because only a single category
# [MainProcess/INFO] model dropped from analysis because only a single category
# C:\Users\Ted\Anaconda3\envs\MBDM\lib\site-packages\ema_workbench\analysis\dimensional_stacking.py:404: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ooi = pd.DataFrame(y[:, np.newaxis], columns=[ooi_label])
# C:\Users\Ted\Anaconda3\envs\MBDM\lib\site-packages\matplotlib\colors.py:587: RuntimeWarning: invalid value encountered in greater
#   xa[xa > self.N - 1] = self._i_over
# C:\Users\Ted\Anaconda3\envs\MBDM\lib\site-packages\matplotlib\colors.py:588: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = self._i_under
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-367015e61a0b> in <module>
#       1 from ema_workbench.analysis import dimensional_stacking
# ----> 2 dimensional_stacking.create_pivot_plot(experiments, y)
#       3 plt.show()
#
# ~\Anaconda3\envs\MBDM\lib\site-packages\ema_workbench\analysis\dimensional_stacking.py in create_pivot_plot(x, y, nr_levels, labels, categories, nbins, bin_labels)
#     409
#     410     fig = plot_pivot_table(pvt, plot_labels=labels,
# --> 411                            plot_cats=categories)
#     412
#     413     return fig
#
# ~\Anaconda3\envs\MBDM\lib\site-packages\ema_workbench\analysis\dimensional_stacking.py in plot_pivot_table(table, plot_labels, plot_cats, figsize, cmap, **kwargs)
#     298         plot_data = table.values
#     299         sns.heatmap(plot_data, ax=ax_plot, cbar_ax=cax, cmap=cmap,
# --> 300                     vmin=0, vmax=1, **kwargs)
#     301
#     302         # set the tick labels
#
# ~\Anaconda3\envs\MBDM\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\envs\MBDM\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     546     if square:
#     547         ax.set_aspect("equal")
# --> 548     plotter.plot(ax, cbar_ax, kwargs)
#     549     return ax
#     550
#
# ~\Anaconda3\envs\MBDM\lib\site-packages\seaborn\matrix.py in plot(self, ax, cax, kws)
#     330         # Possibly rotate them if they overlap
#     331         if hasattr(ax.figure.canvas, "get_renderer"):
# --> 332             ax.figure.draw(ax.figure.canvas.get_renderer())
#     333         if axis_ticklabels_overlap(xtl):
#     334             plt.setp(xtl, rotation="vertical")
#
# ~\Anaconda3\envs\MBDM\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\envs\MBDM\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#    1866             renderer.close_group('figure')
#
# ~\Anaconda3\envs\MBDM\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\Anaconda3\envs\MBDM\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\envs\MBDM\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\Anaconda3\envs\MBDM\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# ~\Anaconda3\envs\MBDM\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\Anaconda3\envs\MBDM\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\envs\MBDM\lib\site-packages\matplotlib\collections.py in draw(self, renderer)
#    2022                 offsets = np.column_stack([xs, ys])
#    2023
# -> 2024         self.update_scalarmappable()
#    2025
#    2026         if not transform.is_affine:
#
# ~\Anaconda3\envs\MBDM\lib\site-packages\matplotlib\collections.py in update_scalarmappable(self)
#     853             return
#     854         if self._is_filled:
# --> 855             self._facecolors = self.to_rgba(self._A, self._alpha)
#     856         elif self._is_stroked:
#     857             self._edgecolors = self.to_rgba(self._A, self._alpha)
#
# ~\Anaconda3\envs\MBDM\lib\site-packages\matplotlib\cm.py in to_rgba(self, x, alpha, bytes, norm)
#     331         if norm:
#     332             x = self.norm(x)
# --> 333         rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     334         return rgba
#     335
#
# ~\Anaconda3\envs\MBDM\lib\site-packages\matplotlib\colors.py in __call__(self, X, alpha, bytes)
#     608                 # override its alpha just as for any other value.
#     609
# --> 610         rgba = lut[xa]
#     611         if not np.iterable(X):
#     612             # Return a tuple if the input was a scalar
#
# IndexError: arrays used as indices must be of integer (or boolean) type
